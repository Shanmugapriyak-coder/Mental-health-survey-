# %%
import pandas as pd
import torch
from torch import nn
from torch import optim 
from sklearn.metrics import accuracy_score,precision_score,recall_score

# %% [markdown]
# ### loading and preprocessing of dataset

# %%
df=pd.read_csv(r"C:\Users\MY Laptop\Desktop\guvi_class\mental health survey\train.csv")

df.drop(['id','Name','City'],axis=1,inplace=True)
df.loc[df['Working Professional or Student'] == 'Working Professional', 'CGPA'] = 0.0
df.loc[df['Working Professional or Student'] == 'Working Professional', 'Academic Pressure'] = 0.0
df.loc[df['Working Professional or Student'] == 'Working Professional', 'Study Satisfaction'] = 0
df['Profession']=df[['Profession']].fillna(df['Profession'].mode()[0])
df['Degree']=df[['Degree']].fillna(df['Degree'].mode()[0])
df['Dietary Habits']=df[['Dietary Habits']].fillna(df['Dietary Habits'].mode()[0])
df['Work Pressure'] = df[['Work Pressure']].fillna(df['Work Pressure'].median())
df['Academic Pressure'] = df[['Academic Pressure']].fillna(df['Academic Pressure'].median())
df['Job Satisfaction'] = df[['Job Satisfaction']].fillna(df['Job Satisfaction'].median())
df['Financial Stress'] = df[['Financial Stress']].fillna(df['Financial Stress'].median())
df['CGPA'] = df[['CGPA']].fillna(df['CGPA'].median())
df['Study Satisfaction'] = df[['Study Satisfaction']].fillna(df['Study Satisfaction'].median())

# Top list 
allowed_profession=['Teacher','Content Writer','Architect','Consultant','HR Manager','Pharmacist','Doctor','Business Analyst','Entrepreneur','Chemist']
df['Profession'] = df['Profession'].where(df['Profession'].isin(allowed_profession), 'Others')
allowed_sleepduration=['Less than 5 hours','7-8 hours','More than 8 hours','5-6 hours','3-4 hours']
df['Sleep Duration'] = df['Sleep Duration'].where(df['Sleep Duration'].isin(allowed_sleepduration), 'Others')
allowed_habits=['Moderate','Unhealthy','Healthy']
df['Dietary Habits'] = df['Dietary Habits'].where(df['Dietary Habits'].isin(allowed_habits), 'Others')
allowed_degree=['Class 12'  ,'B.Ed' ,'B.Arch','B.Com','B.Pharm','BCA','M.Ed','MCA','BBA' ,'BSc']
df['Degree'] = df['Degree'].where(df['Degree'].isin(allowed_degree), 'Others')


nominal_data=['Gender','Working Professional or Student','Profession','Degree','Sleep Duration','Dietary Habits'] #OHC
ordinal_data=['Family History of Mental Illness', 'Have you ever had suicidal thoughts ?']
df['Family History of Mental Illness']=df['Family History of Mental Illness'].replace({'No':0,'Yes':1})
df['Have you ever had suicidal thoughts ?']=df['Have you ever had suicidal thoughts ?'].replace({'No':0,'Yes':1})
df=pd.get_dummies(df,columns=nominal_data,dtype='int')

# handing outlier 

import numpy as np
outliers=['Academic Pressure','CGPA',
       'Study Satisfaction']
for col in outliers:

    Q1 = df[col].quantile(0.25)  # 25th percentile
    Q3 = df[col].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  # Interquartile range

    # Define lower and upper bound
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Cap values at lower and upper bound
    df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
    df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])
# Out:
# C:\Users\MY Laptop\AppData\Local\Temp\ipykernel_7728\2431601658.py:30: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Family History of Mental Illness']=df['Family History of Mental Illness'].replace({'No':0,'Yes':1})
# C:\Users\MY Laptop\AppData\Local\Temp\ipykernel_7728\2431601658.py:31: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Have you ever had suicidal thoughts ?']=df['Have you ever had suicidal thoughts ?'].replace({'No':0,'Yes':1})

# %%
class DNN(nn.Module):
    def __init__(self,input_size,hidden_size,output_size):
        super(DNN,self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size,hidden_size[0]),
            nn.ReLU(),
            nn.Linear(hidden_size[0],hidden_size[1]),
            nn.ReLU(),
            nn.Linear(hidden_size[1],hidden_size[2]),
            nn.ReLU(),
            nn.Linear(hidden_size[2],hidden_size[3]),
            nn.ReLU(),
            nn.Linear(hidden_size[3],hidden_size[4]),
            nn.ReLU(),
            nn.Linear(hidden_size[4],output_size),
            nn.Sigmoid()
        )
        
    def forward(self,X):
        X = self.layers(X)
        return X
model = DNN(input_size,hidden_size,output_size)
criterion= nn.BCELoss()
# optimizer = optim.SGD(model.parameters())
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

num_epoch= 100
for epoch in range(num_epoch):
    # optimizer.zero_grad()
    # output = model(X)
    # loss = criterion(output,y)
    # loss.backward()
    # optimizer.step()
    # print(f"epoch {epoch}/{num_epoch}: loss: {loss.item()}")
    optimizer.zero_grad()
    output = model(X)
    loss = criterion(output,y)
    loss.backward()
    optimizer.step()    
    predicted = (output > 0.5).float()  # Binary prediction
    all_preds = predicted.cpu().numpy()
    all_labels = y.cpu().numpy()
    
    # Calculate metrics
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds)
    
    # Print metrics
    print(f"epoch {epoch}/{num_epoch}: loss: {loss.item():.4f}, accuracy: {accuracy:.4f}, precision: {precision:.4f}, recall: {recall:.4f}")
# Out:
# epoch 0/100: loss: 0.6963, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 1/100: loss: 0.6936, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 2/100: loss: 0.6893, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 3/100: loss: 0.6886, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 4/100: loss: 0.6868, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 5/100: loss: 0.6844, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 6/100: loss: 0.6820, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 7/100: loss: 0.6796, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 8/100: loss: 0.6777, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 9/100: loss: 0.6756, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 10/100: loss: 0.6733, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 11/100: loss: 0.6705, accuracy: 0.5000, precision: 0.5000, recall: 1.0000
# epoch 12/100: loss: 0.6671, accuracy: 0.7175, precision: 0.6415, recall: 0.9856
# epoch 13/100: loss: 0.6631, accuracy: 0.7883, precision: 0.7089, recall: 0.9785
# epoch 14/100: loss: 0.6582, accuracy: 0.8316, precision: 0.7577, recall: 0.9749
# epoch 15/100: loss: 0.6520, accuracy: 0.8401, precision: 0.7676, recall: 0.9758
# epoch 16/100: loss: 0.6446, accuracy: 0.8356, precision: 0.7608, recall: 0.9791
# epoch 17/100: loss: 0.6348, accuracy: 0.8479, precision: 0.7765, recall: 0.9768
# epoch 18/100: loss: 0.6226, accuracy: 0.8637, precision: 0.7994, recall: 0.9711
# epoch 19/100: loss: 0.6074, accuracy: 0.8604, precision: 0.7933, recall: 0.9748
# epoch 20/100: loss: 0.5893, accuracy: 0.8473, precision: 0.7742, recall: 0.9805
# epoch 21/100: loss: 0.5667, accuracy: 0.8570, precision: 0.7876, recall: 0.9777
# epoch 22/100: loss: 0.5413, accuracy: 0.8651, precision: 0.7996, recall: 0.9745
# epoch 23/100: loss: 0.5169, accuracy: 0.8633, precision: 0.7965, recall: 0.9758
# epoch 24/100: loss: 0.4956, accuracy: 0.8826, precision: 0.8289, recall: 0.9642
# epoch 25/100: loss: 0.4799, accuracy: 0.8890, precision: 0.8407, recall: 0.9598
# epoch 26/100: loss: 0.4701, accuracy: 0.8956, precision: 0.8564, recall: 0.9506
# epoch 27/100: loss: 0.4642, accuracy: 0.9004, precision: 0.8775, recall: 0.9307
# epoch 28/100: loss: 0.4605, accuracy: 0.9017, precision: 0.8740, recall: 0.9387
# epoch 29/100: loss: 0.4597, accuracy: 0.8957, precision: 0.9079, recall: 0.8808
# epoch 30/100: loss: 0.4565, accuracy: 0.9052, precision: 0.8784, recall: 0.9407
# epoch 31/100: loss: 0.4479, accuracy: 0.9028, precision: 0.9053, recall: 0.8996
# epoch 32/100: loss: 0.4457, accuracy: 0.8995, precision: 0.9143, recall: 0.8815
# epoch 33/100: loss: 0.4410, accuracy: 0.9100, precision: 0.8915, recall: 0.9338
# epoch 34/100: loss: 0.4332, accuracy: 0.9095, precision: 0.9053, recall: 0.9146
# epoch 35/100: loss: 0.4298, accuracy: 0.9074, precision: 0.9161, recall: 0.8970
# epoch 36/100: loss: 0.4241, accuracy: 0.9146, precision: 0.8925, recall: 0.9428
# epoch 37/100: loss: 0.4170, accuracy: 0.9149, precision: 0.9080, recall: 0.9234
# epoch 38/100: loss: 0.4120, accuracy: 0.9164, precision: 0.9077, recall: 0.9270
# epoch 39/100: loss: 0.4096, accuracy: 0.9156, precision: 0.8839, recall: 0.9568
# epoch 40/100: loss: 0.4111, accuracy: 0.9140, precision: 0.9258, recall: 0.9001
# epoch 41/100: loss: 0.4045, accuracy: 0.9118, precision: 0.8722, recall: 0.9651
# epoch 42/100: loss: 0.3977, accuracy: 0.9202, precision: 0.9133, recall: 0.9285
# epoch 43/100: loss: 0.3924, accuracy: 0.9208, precision: 0.9038, recall: 0.9420
# epoch 44/100: loss: 0.3929, accuracy: 0.9149, precision: 0.8780, recall: 0.9638
# epoch 45/100: loss: 0.3927, accuracy: 0.9201, precision: 0.9263, recall: 0.9129
# epoch 46/100: loss: 0.3829, accuracy: 0.9211, precision: 0.8961, recall: 0.9526
# epoch 47/100: loss: 0.3830, accuracy: 0.9176, precision: 0.8830, recall: 0.9628
# epoch 48/100: loss: 0.3832, accuracy: 0.9219, precision: 0.9288, recall: 0.9139
# epoch 49/100: loss: 0.3736, accuracy: 0.9243, precision: 0.9070, recall: 0.9456
# epoch 50/100: loss: 0.3771, accuracy: 0.9177, precision: 0.8813, recall: 0.9654
# epoch 51/100: loss: 0.3724, accuracy: 0.9240, precision: 0.9273, recall: 0.9200
# epoch 52/100: loss: 0.3675, accuracy: 0.9255, precision: 0.9228, recall: 0.9286
# epoch 53/100: loss: 0.3688, accuracy: 0.9206, precision: 0.8880, recall: 0.9626
# epoch 54/100: loss: 0.3608, accuracy: 0.9264, precision: 0.9148, recall: 0.9403
# epoch 55/100: loss: 0.3623, accuracy: 0.9249, precision: 0.9307, recall: 0.9183
# epoch 56/100: loss: 0.3564, accuracy: 0.9263, precision: 0.9104, recall: 0.9457
# epoch 57/100: loss: 0.3567, accuracy: 0.9245, precision: 0.9000, recall: 0.9552
# epoch 58/100: loss: 0.3529, accuracy: 0.9269, precision: 0.9259, recall: 0.9282
# epoch 59/100: loss: 0.3511, accuracy: 0.9268, precision: 0.9281, recall: 0.9253
# epoch 60/100: loss: 0.3488, accuracy: 0.9264, precision: 0.9066, recall: 0.9507
# epoch 61/100: loss: 0.3457, accuracy: 0.9274, precision: 0.9118, recall: 0.9463
# epoch 62/100: loss: 0.3448, accuracy: 0.9275, precision: 0.9303, recall: 0.9242
# epoch 63/100: loss: 0.3410, accuracy: 0.9283, precision: 0.9225, recall: 0.9352
# epoch 64/100: loss: 0.3408, accuracy: 0.9270, precision: 0.9069, recall: 0.9518
# epoch 65/100: loss: 0.3370, accuracy: 0.9285, precision: 0.9229, recall: 0.9353
# epoch 66/100: loss: 0.3362, accuracy: 0.9285, precision: 0.9299, recall: 0.9269
# epoch 67/100: loss: 0.3336, accuracy: 0.9281, precision: 0.9136, recall: 0.9457
# epoch 68/100: loss: 0.3316, accuracy: 0.9283, precision: 0.9151, recall: 0.9442
# epoch 69/100: loss: 0.3305, accuracy: 0.9287, precision: 0.9299, recall: 0.9274
# epoch 70/100: loss: 0.3276, accuracy: 0.9293, precision: 0.9219, recall: 0.9380
# epoch 71/100: loss: 0.3269, accuracy: 0.9281, precision: 0.9127, recall: 0.9468
# epoch 72/100: loss: 0.3247, accuracy: 0.9294, precision: 0.9280, recall: 0.9310
# epoch 73/100: loss: 0.3227, accuracy: 0.9296, precision: 0.9265, recall: 0.9334
# epoch 74/100: loss: 0.3218, accuracy: 0.9285, precision: 0.9140, recall: 0.9460
# epoch 75/100: loss: 0.3193, accuracy: 0.9299, precision: 0.9262, recall: 0.9342
# epoch 76/100: loss: 0.3180, accuracy: 0.9298, precision: 0.9285, recall: 0.9314
# epoch 77/100: loss: 0.3166, accuracy: 0.9293, precision: 0.9166, recall: 0.9445
# epoch 78/100: loss: 0.3144, accuracy: 0.9303, precision: 0.9253, recall: 0.9362
# epoch 79/100: loss: 0.3132, accuracy: 0.9302, precision: 0.9292, recall: 0.9312
# epoch 80/100: loss: 0.3117, accuracy: 0.9301, precision: 0.9190, recall: 0.9434
# epoch 81/100: loss: 0.3097, accuracy: 0.9307, precision: 0.9249, recall: 0.9376
# epoch 82/100: loss: 0.3086, accuracy: 0.9308, precision: 0.9296, recall: 0.9322
# epoch 83/100: loss: 0.3071, accuracy: 0.9306, precision: 0.9201, recall: 0.9432
# epoch 84/100: loss: 0.3053, accuracy: 0.9313, precision: 0.9256, recall: 0.9380
# epoch 85/100: loss: 0.3041, accuracy: 0.9313, precision: 0.9287, recall: 0.9345
# epoch 86/100: loss: 0.3027, accuracy: 0.9310, precision: 0.9206, recall: 0.9433
# epoch 87/100: loss: 0.3011, accuracy: 0.9316, precision: 0.9268, recall: 0.9372
# epoch 88/100: loss: 0.2998, accuracy: 0.9318, precision: 0.9272, recall: 0.9370
# epoch 89/100: loss: 0.2986, accuracy: 0.9313, precision: 0.9211, recall: 0.9434
# epoch 90/100: loss: 0.2972, accuracy: 0.9320, precision: 0.9287, recall: 0.9359
# epoch 91/100: loss: 0.2957, accuracy: 0.9319, precision: 0.9250, recall: 0.9400
# epoch 92/100: loss: 0.2944, accuracy: 0.9319, precision: 0.9239, recall: 0.9414
# epoch 93/100: loss: 0.2932, accuracy: 0.9323, precision: 0.9293, recall: 0.9358
# epoch 94/100: loss: 0.2919, accuracy: 0.9319, precision: 0.9228, recall: 0.9427
# epoch 95/100: loss: 0.2906, accuracy: 0.9324, precision: 0.9285, recall: 0.9370
# epoch 96/100: loss: 0.2893, accuracy: 0.9324, precision: 0.9268, recall: 0.9390
# epoch 97/100: loss: 0.2881, accuracy: 0.9325, precision: 0.9252, recall: 0.9409
# epoch 98/100: loss: 0.2870, accuracy: 0.9325, precision: 0.9300, recall: 0.9354
# epoch 99/100: loss: 0.2858, accuracy: 0.9323, precision: 0.9237, recall: 0.9425

# %%
class DNN(nn.Module):
    def __init__(self,input_size,hidden_size,output_size):
        super(DNN,self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size,hidden_size[0]),
            nn.ReLU(),
            nn.Linear(hidden_size[0],hidden_size[1]),
            nn.ReLU(),
            nn.Linear(hidden_size[1],hidden_size[2]),
            nn.ReLU(),
            nn.Linear(hidden_size[2],hidden_size[3]),
            nn.ReLU(),
            nn.Linear(hidden_size[3],output_size),
            nn.Sigmoid()
        )
        
    def forward(self,X):
        X = self.layers(X)
        return X
model = DNN(input_size,hidden_size,output_size)
criterion= nn.BCELoss()
# optimizer = optim.SGD(model.parameters())
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

num_epoch= 100
for epoch in range(num_epoch):
    # optimizer.zero_grad()
    # output = model(X)
    # loss = criterion(output,y)
    # loss.backward()
    # optimizer.step()
    # print(f"epoch {epoch}/{num_epoch}: loss: {loss.item()}")
    optimizer.zero_grad()
    output = model(X)
    loss = criterion(output,y)
    loss.backward()
    optimizer.step()    
    predicted = (output > 0.5).float()  # Binary prediction
    all_preds = predicted.cpu().numpy()
    all_labels = y.cpu().numpy()
    
    # Calculate metrics
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds)
    
    # Print metrics
    print(f"epoch {epoch}/{num_epoch}: loss: {loss.item():.4f}, accuracy: {accuracy:.4f}, precision: {precision:.4f}, recall: {recall:.4f}")
# Out:
# epoch 0/100: loss: 0.6981, accuracy: 0.4927, precision: 0.4963, recall: 0.9831
# epoch 1/100: loss: 0.6812, accuracy: 0.5003, precision: 0.5749, recall: 0.0025
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# epoch 2/100: loss: 0.6578, accuracy: 0.5000, precision: 0.0000, recall: 0.0000
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# epoch 3/100: loss: 0.6424, accuracy: 0.5000, precision: 0.0000, recall: 0.0000
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# epoch 4/100: loss: 0.6312, accuracy: 0.5000, precision: 0.0000, recall: 0.0000
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# epoch 5/100: loss: 0.6097, accuracy: 0.5000, precision: 0.0000, recall: 0.0000
# epoch 6/100: loss: 0.5878, accuracy: 0.5832, precision: 0.9593, recall: 0.1737
# epoch 7/100: loss: 0.5679, accuracy: 0.7305, precision: 0.9235, recall: 0.5026
# epoch 8/100: loss: 0.5422, accuracy: 0.7987, precision: 0.9055, recall: 0.6670
# epoch 9/100: loss: 0.5127, accuracy: 0.8089, precision: 0.9021, recall: 0.6930
# epoch 10/100: loss: 0.4909, accuracy: 0.8127, precision: 0.9021, recall: 0.7015
# epoch 11/100: loss: 0.4718, accuracy: 0.8271, precision: 0.8964, recall: 0.7398
# epoch 12/100: loss: 0.4518, accuracy: 0.8480, precision: 0.8817, recall: 0.8039
# epoch 13/100: loss: 0.4337, accuracy: 0.8616, precision: 0.8642, recall: 0.8581
# epoch 14/100: loss: 0.4141, accuracy: 0.8665, precision: 0.8588, recall: 0.8771
# epoch 15/100: loss: 0.3933, accuracy: 0.8691, precision: 0.8641, recall: 0.8760
# epoch 16/100: loss: 0.3724, accuracy: 0.8726, precision: 0.8633, recall: 0.8854
# epoch 17/100: loss: 0.3509, accuracy: 0.8763, precision: 0.8528, recall: 0.9095
# epoch 18/100: loss: 0.3318, accuracy: 0.8783, precision: 0.8488, recall: 0.9207
# epoch 19/100: loss: 0.3145, accuracy: 0.8814, precision: 0.8612, recall: 0.9093
# epoch 20/100: loss: 0.3015, accuracy: 0.8839, precision: 0.8624, recall: 0.9136
# epoch 21/100: loss: 0.2937, accuracy: 0.8864, precision: 0.8554, recall: 0.9301
# epoch 22/100: loss: 0.2869, accuracy: 0.8895, precision: 0.8730, recall: 0.9116
# epoch 23/100: loss: 0.2796, accuracy: 0.8924, precision: 0.8670, recall: 0.9271
# epoch 24/100: loss: 0.2716, accuracy: 0.8951, precision: 0.8721, recall: 0.9261
# epoch 25/100: loss: 0.2636, accuracy: 0.8977, precision: 0.8799, recall: 0.9210
# epoch 26/100: loss: 0.2587, accuracy: 0.8983, precision: 0.8626, recall: 0.9476
# epoch 27/100: loss: 0.2635, accuracy: 0.8979, precision: 0.9004, recall: 0.8949
# epoch 28/100: loss: 0.2600, accuracy: 0.8956, precision: 0.8474, recall: 0.9649
# epoch 29/100: loss: 0.2428, accuracy: 0.9059, precision: 0.8875, recall: 0.9297
# epoch 30/100: loss: 0.2472, accuracy: 0.9042, precision: 0.9021, recall: 0.9069
# epoch 31/100: loss: 0.2439, accuracy: 0.9031, precision: 0.8608, recall: 0.9616
# epoch 32/100: loss: 0.2329, accuracy: 0.9097, precision: 0.8819, recall: 0.9462
# epoch 33/100: loss: 0.2372, accuracy: 0.9091, precision: 0.9053, recall: 0.9137
# epoch 34/100: loss: 0.2272, accuracy: 0.9114, precision: 0.8821, recall: 0.9497
# epoch 35/100: loss: 0.2257, accuracy: 0.9120, precision: 0.8808, recall: 0.9528
# epoch 36/100: loss: 0.2248, accuracy: 0.9122, precision: 0.9103, recall: 0.9145
# epoch 37/100: loss: 0.2169, accuracy: 0.9156, precision: 0.8996, recall: 0.9356
# epoch 38/100: loss: 0.2195, accuracy: 0.9146, precision: 0.8832, recall: 0.9555
# epoch 39/100: loss: 0.2135, accuracy: 0.9170, precision: 0.9104, recall: 0.9249
# epoch 40/100: loss: 0.2106, accuracy: 0.9183, precision: 0.9113, recall: 0.9268
# epoch 41/100: loss: 0.2110, accuracy: 0.9181, precision: 0.8897, recall: 0.9545
# epoch 42/100: loss: 0.2046, accuracy: 0.9207, precision: 0.9090, recall: 0.9349
# epoch 43/100: loss: 0.2047, accuracy: 0.9202, precision: 0.9173, recall: 0.9236
# epoch 44/100: loss: 0.2025, accuracy: 0.9215, precision: 0.8975, recall: 0.9516
# epoch 45/100: loss: 0.1981, accuracy: 0.9234, precision: 0.9088, recall: 0.9412
# epoch 46/100: loss: 0.1987, accuracy: 0.9224, precision: 0.9211, recall: 0.9240
# epoch 47/100: loss: 0.1957, accuracy: 0.9243, precision: 0.9045, recall: 0.9488
# epoch 48/100: loss: 0.1931, accuracy: 0.9252, precision: 0.9098, recall: 0.9439
# epoch 49/100: loss: 0.1935, accuracy: 0.9246, precision: 0.9235, recall: 0.9258
# epoch 50/100: loss: 0.1909, accuracy: 0.9263, precision: 0.9091, recall: 0.9475
# epoch 51/100: loss: 0.1891, accuracy: 0.9269, precision: 0.9128, recall: 0.9439
# epoch 52/100: loss: 0.1893, accuracy: 0.9262, precision: 0.9249, recall: 0.9276
# epoch 53/100: loss: 0.1874, accuracy: 0.9274, precision: 0.9114, recall: 0.9469
# epoch 54/100: loss: 0.1858, accuracy: 0.9281, precision: 0.9167, recall: 0.9418
# epoch 55/100: loss: 0.1859, accuracy: 0.9278, precision: 0.9254, recall: 0.9306
# epoch 56/100: loss: 0.1848, accuracy: 0.9283, precision: 0.9127, recall: 0.9472
# epoch 57/100: loss: 0.1832, accuracy: 0.9292, precision: 0.9211, recall: 0.9387
# epoch 58/100: loss: 0.1828, accuracy: 0.9291, precision: 0.9250, recall: 0.9339
# epoch 59/100: loss: 0.1825, accuracy: 0.9291, precision: 0.9140, recall: 0.9474
# epoch 60/100: loss: 0.1812, accuracy: 0.9298, precision: 0.9253, recall: 0.9350
# epoch 61/100: loss: 0.1802, accuracy: 0.9301, precision: 0.9228, recall: 0.9387
# epoch 62/100: loss: 0.1800, accuracy: 0.9300, precision: 0.9171, recall: 0.9455
# epoch 63/100: loss: 0.1795, accuracy: 0.9303, precision: 0.9283, recall: 0.9328
# epoch 64/100: loss: 0.1785, accuracy: 0.9308, precision: 0.9196, recall: 0.9440
# epoch 65/100: loss: 0.1776, accuracy: 0.9311, precision: 0.9227, recall: 0.9409
# epoch 66/100: loss: 0.1774, accuracy: 0.9311, precision: 0.9274, recall: 0.9355
# epoch 67/100: loss: 0.1771, accuracy: 0.9314, precision: 0.9188, recall: 0.9464
# epoch 68/100: loss: 0.1764, accuracy: 0.9316, precision: 0.9283, recall: 0.9354
# epoch 69/100: loss: 0.1757, accuracy: 0.9318, precision: 0.9226, recall: 0.9427
# epoch 70/100: loss: 0.1752, accuracy: 0.9320, precision: 0.9236, recall: 0.9418
# epoch 71/100: loss: 0.1749, accuracy: 0.9322, precision: 0.9281, recall: 0.9370
# epoch 72/100: loss: 0.1747, accuracy: 0.9319, precision: 0.9206, recall: 0.9454
# epoch 73/100: loss: 0.1743, accuracy: 0.9323, precision: 0.9297, recall: 0.9355
# epoch 74/100: loss: 0.1738, accuracy: 0.9323, precision: 0.9218, recall: 0.9448
# epoch 75/100: loss: 0.1732, accuracy: 0.9330, precision: 0.9280, recall: 0.9389
# epoch 76/100: loss: 0.1728, accuracy: 0.9331, precision: 0.9256, recall: 0.9419
# epoch 77/100: loss: 0.1725, accuracy: 0.9332, precision: 0.9252, recall: 0.9426
# epoch 78/100: loss: 0.1722, accuracy: 0.9333, precision: 0.9286, recall: 0.9387
# epoch 79/100: loss: 0.1720, accuracy: 0.9332, precision: 0.9232, recall: 0.9451
# epoch 80/100: loss: 0.1719, accuracy: 0.9332, precision: 0.9308, recall: 0.9359
# epoch 81/100: loss: 0.1718, accuracy: 0.9332, precision: 0.9214, recall: 0.9472
# epoch 82/100: loss: 0.1719, accuracy: 0.9331, precision: 0.9335, recall: 0.9327
# epoch 83/100: loss: 0.1722, accuracy: 0.9328, precision: 0.9182, recall: 0.9503
# epoch 84/100: loss: 0.1730, accuracy: 0.9328, precision: 0.9377, recall: 0.9272
# epoch 85/100: loss: 0.1741, accuracy: 0.9322, precision: 0.9130, recall: 0.9555
# epoch 86/100: loss: 0.1760, accuracy: 0.9311, precision: 0.9425, recall: 0.9182
# epoch 87/100: loss: 0.1763, accuracy: 0.9315, precision: 0.9085, recall: 0.9596
# epoch 88/100: loss: 0.1749, accuracy: 0.9316, precision: 0.9420, recall: 0.9198
# epoch 89/100: loss: 0.1709, accuracy: 0.9333, precision: 0.9183, recall: 0.9512
# epoch 90/100: loss: 0.1689, accuracy: 0.9346, precision: 0.9283, recall: 0.9420
# epoch 91/100: loss: 0.1701, accuracy: 0.9342, precision: 0.9357, recall: 0.9324
# epoch 92/100: loss: 0.1718, accuracy: 0.9332, precision: 0.9152, recall: 0.9549
# epoch 93/100: loss: 0.1715, accuracy: 0.9334, precision: 0.9393, recall: 0.9266
# epoch 94/100: loss: 0.1690, accuracy: 0.9340, precision: 0.9214, recall: 0.9490
# epoch 95/100: loss: 0.1679, accuracy: 0.9350, precision: 0.9277, recall: 0.9435
# epoch 96/100: loss: 0.1689, accuracy: 0.9347, precision: 0.9357, recall: 0.9335
# epoch 97/100: loss: 0.1697, accuracy: 0.9339, precision: 0.9180, recall: 0.9529
# epoch 98/100: loss: 0.1691, accuracy: 0.9347, precision: 0.9373, recall: 0.9317
# epoch 99/100: loss: 0.1674, accuracy: 0.9349, precision: 0.9248, recall: 0.9469
